# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# Function for area calculation
def calculate_area(mask):
    # Calculate the area of the segmented region
    area = np.sum(mask) / 255.0  # Convert to binary mask (0 or 255)
    return area

# Function for intensity analysis
def analyze_intensity(segmented_image):
    # Convert the segmented image to grayscale
    gray_image = cv2.cvtColor(segmented_image, cv2.COLOR_BGR2GRAY)
    
    # Compute the mean intensity of the segmented region
    mean_intensity = np.mean(gray_image)
    return mean_intensity

# Function for comparing growth over n days
def compare_growth(data):
    # Assuming 'data' is a list of area or intensity values for each day
    growth_rate = []
    for i in range(1, len(data)):
        rate = (data[i] - data[i-1]) / data[i-1]
        growth_rate.append(rate)
    return growth_rate

# Load segmented images for each day
segmented_images = []
clicks_per_day = 3
total_days = 12

for day in range(1, total_days + 1):
    for click in range(1, clicks_per_day + 1):
        image_path = f"segmented_image_{(day-1)*clicks_per_day + click}.jpg"
        if os.path.exists(image_path):
            segmented_image = cv2.imread(image_path)
            segmented_images.append(segmented_image)
        else:
            print(f"Error: Image for day {day}, click {click} not found.")
            segmented_images.append(None)

# Calculate area and intensity for each day
area_data = []
intensity_data = []
for segmented_image in segmented_images:
    if segmented_image is not None:
        # Threshold the image to obtain the mask of the black fungus colony
        _, binary_image = cv2.threshold(cv2.cvtColor(segmented_image, cv2.COLOR_BGR2GRAY), 1, 255, cv2.THRESH_BINARY)
        area = calculate_area(binary_image)
        intensity = analyze_intensity(segmented_image)
        area_data.append(area)
        intensity_data.append(intensity)
    else:
        area_data.append(None)
        intensity_data.append(None)

# Compare growth over n days
area_growth_rate = compare_growth(area_data)
intensity_growth_rate = compare_growth(intensity_data)

# Plotting the growth rate graph
total_images = len(segmented_images)  # Calculate total images
total_days = total_images // clicks_per_day  # Calculate total days
days = np.arange(1, total_days + 1)  # Generate x-axis values for each day
plt.plot(days, area_growth_rate[:total_days], marker='o', label='Area Growth Rate')
plt.plot(days, intensity_growth_rate[:total_days], marker='x', label='Intensity Growth Rate')
plt.xlabel('Days')
plt.ylabel('Growth Rate')
plt.title('Average Growth Rate Days and Time')
plt.legend()
plt.grid(True)

plt.savefig('growth_rate_graph.png')

plt.show()

# Print or visualize the results
for idx, (segmented_image, area, intensity) in enumerate(zip(segmented_images, area_data, intensity_data), start=1):
    if segmented_image is not None:
        # Calculate the corresponding day
        day = (idx - 1) // clicks_per_day + 1
        
        # Display segmented image
        cv2.imshow(f"Day {day}, Click {idx % clicks_per_day if idx % clicks_per_day != 0 else clicks_per_day} - Segmented Image", segmented_image)
        
        # Print area and intensity data
        print(f"Day {day}, Click {idx % clicks_per_day if idx % clicks_per_day != 0 else clicks_per_day} - Area: {area} pixels squared")
        print(f"Day {day}, Click {idx % clicks_per_day if idx % clicks_per_day != 0 else clicks_per_day} - Mean Intensity: {intensity}")

        # Display image of fungus growth
        cv2.imshow(f"Fungus Growth - Day {day}, Click {idx % clicks_per_day if idx % clicks_per_day != 0 else clicks_per_day}", segmented_image)
        
        # Wait for key press to move to next image or exit
        key = cv2.waitKey(0)  # Changed from cv2.waitKey(1)
        if key == 27:  # Esc key to exit
            break
    else:
        print(f"Error: Image for day {day}, click {click} not found.")

cv2.destroyAllWindows()

print("Area Data (in pixels squared):\n", area_data)
print("Intensity Data (mean intensity):\n", intensity_data)
print("Area Growth Rate:\n", area_growth_rate)
print("Intensity Growth Rate:\n", intensity_growth_rate)
# Out:
# Day 1, Click 1 - Area: 26371.0 pixels squared
# Day 1, Click 1 - Mean Intensity: 2.2184408184408184
# Day 1, Click 2 - Area: 23342.0 pixels squared
# Day 1, Click 2 - Mean Intensity: 2.064685231136844
# Day 1, Click 3 - Area: 23342.0 pixels squared
# Day 1, Click 3 - Mean Intensity: 2.064685231136844
# Day 2, Click 1 - Area: 31337.0 pixels squared
# Day 2, Click 1 - Mean Intensity: 2.5948423858101277
# Day 2, Click 2 - Area: 31918.0 pixels squared
# Day 2, Click 2 - Mean Intensity: 2.6262255307416598
# Day 2, Click 3 - Area: 34455.0 pixels squared
# Day 2, Click 3 - Mean Intensity: 2.8366620715007813
# Day 3, Click 1 - Area: 36104.0 pixels squared
# Day 3, Click 1 - Mean Intensity: 2.8911092730447567
# Day 3, Click 2 - Area: 36414.0 pixels squared
# Day 3, Click 2 - Mean Intensity: 2.8959250068927487
# Day 3, Click 3 - Area: 33293.0 pixels squared
# Day 3, Click 3 - Mean Intensity: 2.6567888980792205
# Day 4, Click 1 - Area: 36104.0 pixels squared
# Day 4, Click 1 - Mean Intensity: 2.8911092730447567
# Day 4, Click 2 - Area: 36414.0 pixels squared
# Day 4, Click 2 - Mean Intensity: 2.8959250068927487
# Day 4, Click 3 - Area: 33293.0 pixels squared
# Day 4, Click 3 - Mean Intensity: 2.6567888980792205
# Day 5, Click 1 - Area: 24342.0 pixels squared
# Day 5, Click 1 - Mean Intensity: 2.080253653156879
# Day 5, Click 2 - Area: 24591.0 pixels squared
# Day 5, Click 2 - Mean Intensity: 2.1289587354103485
# Day 5, Click 3 - Area: 25105.0 pixels squared
# Day 5, Click 3 - Mean Intensity: 2.1956695156695156
# Day 6, Click 1 - Area: 20629.0 pixels squared
# Day 6, Click 1 - Mean Intensity: 1.8590092822350888
# Day 6, Click 2 - Area: 20494.0 pixels squared
# Day 6, Click 2 - Mean Intensity: 1.8413197316423122
# Day 6, Click 3 - Area: 21277.0 pixels squared
# Day 6, Click 3 - Mean Intensity: 1.8648984468339307
# Day 7, Click 1 - Area: 40078.0 pixels squared
# Day 7, Click 1 - Mean Intensity: 3.356198878779524
# Day 7, Click 2 - Area: 40488.0 pixels squared
# Day 7, Click 2 - Mean Intensity: 3.4036945133719327
# Day 7, Click 3 - Area: 40157.0 pixels squared
# Day 7, Click 3 - Mean Intensity: 3.4150427350427353
# Day 8, Click 1 - Area: 44225.0 pixels squared
# Day 8, Click 1 - Mean Intensity: 3.7525227460711332
# Day 8, Click 2 - Area: 44366.0 pixels squared
# Day 8, Click 2 - Mean Intensity: 3.8217149159084642
# Day 8, Click 3 - Area: 43805.0 pixels squared
# Day 8, Click 3 - Mean Intensity: 3.7589412737799837
# Day 9, Click 1 - Area: 42539.0 pixels squared
# Day 9, Click 1 - Mean Intensity: 3.5574009741751675
# Day 9, Click 2 - Area: 42211.0 pixels squared
# Day 9, Click 2 - Mean Intensity: 3.564973807554453
# Day 9, Click 3 - Area: 41827.0 pixels squared
# Day 9, Click 3 - Mean Intensity: 3.5306093189964156
# Day 10, Click 1 - Area: 42487.0 pixels squared
# Day 10, Click 1 - Mean Intensity: 3.536954324051098
# Day 10, Click 2 - Area: 43096.0 pixels squared
# Day 10, Click 2 - Mean Intensity: 3.610921790276629
# Day 10, Click 3 - Area: 42982.0 pixels squared
# Day 10, Click 3 - Mean Intensity: 3.6294090616671264
